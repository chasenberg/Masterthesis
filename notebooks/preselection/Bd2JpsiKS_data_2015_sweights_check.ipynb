# %%
import ROOT
from rootpy.tree import Tree, TreeModel, FloatCol, IntCol
from rootpy.io import root_open
from ROOT import gROOT, TCanvas, TF1, TFile, TTree, gRandom, TH1F

from ROOT import RooRealVar, RooFormulaVar, RooVoigtian, RooChebychev, RooArgList, \
                 RooArgSet, RooAddPdf, RooDataSet, RooCategory, RooSimultaneous, \
                 RooBreitWigner, RooCBShape, RooFFTConvPdf, RooGaussian,RooExponential, \
                 RooBinning, kRed, kBlue, kDotted,TString,RooAbsData, RooPlot, TCut, RooAbsData

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import os, sys, time, random

from ROOT import TTree, TFile

# from root_numpy import root2array, rec2array, array2root

import pandas as pd
import numpy as np
import scipy 
import root_pandas as rp
import root_numpy as ry 

import pandas.core.common as com
from pandas.core.index import Index
from pandas.tools import plotting
from pandas.tools.plotting import scatter_matrix

from tqdm import tqdm_notebook

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import Imputer, StandardScaler
from sklearn.externals import joblib
from sklearn.metrics import classification_report, roc_curve, auc, roc_auc_score

sys.path.append('/home/chasenberg/repos/')
sys.path.append('/home/chasenberg/repos/dopy')
import dopy as dpp
from dopy import * 
from dopy.dolearn.sklearn_utils import plot_roc_curve, plot_classifier_output, plot_correlations
from dopy.dolearn.sklearn_utils import plot_feature_importances, plot_classifier_output, classify_unseen_data
#from dopy.sklearn_utils import plot_bdt_vars
from dopy.doplot.plotting import Plotter, Plot
from dopy.doanalysis.df_utils import add_min_max, add_eta
# Out:
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#directories and files 
data_dir = '/fhgfs/users/chasenberg/data/2015/jpsiks/flattened/'
data_file ='Bd2JpsiKS_data_2015_flattened_SWeights.root'

mc_dir = '/fhgfs/users/chasenberg/mc/dimuon_stripping/'
mc_file = 'Bd2JpsiKS_Dimuon_flattened.root'

data_dir = os.path.join(data_dir, data_file)
mc_dir = os.path.join(mc_dir, mc_file)

# %%
#criteria and information for read in data
branch_names_data = ['B0_M','B0_FitDaughtersConst*','idxPV','B0_FitPVConst_status','B0_FitPVConst_KS0_tau','B0_FitPVConst_KS0_tau*','B0_L0MuonDecision_TOS','B0_Hlt1TrackMuonDecision_TOS','B0_Hlt2DiMuonJPsiDecision_TOS']
cut_string_data = 'B0_FitDaughtersConst_J_psi_1S_PT_flat>=2000&B0_FitDaughtersConst_status==0&B0_FitPVConst_status==0&idxPV==0&B0_FitDaughtersConst_M>5450&((B0_L0Global_TOS==1)|(B0_Hlt1DiMuonHighMassDecision_TOS==1)|B0_Hlt2DiMuonDetachedJPsiDecision_TOS==1)'
tree_data = 'Bd2JspiKs'

# %%
#criteria and information for read in mc
branch_names_mc = ['B0_M','B0_FitDaughtersConst*','idxPV','B0_FitPVConst_status','B0_FitPVConst_KS0_tau*','B0_BKGCAT','B0_L0MuonDecision_TOS','B0_Hlt1TrackMuonDecision_TOS','B0_Hlt2DiMuonJPsiDecision_TOS']
cut_string_mc = 'B0_FitDaughtersConst_J_psi_1S_PT_flat>=2000&B0_FitDaughtersConst_status==0&B0_FitPVConst_status==0&idxPV==0&B0_FitDaughtersConst_M<5350&B0_FitDaughtersConst_M>5220&((B0_BKGCAT==10)|(B0_BKGCAT==50))&((B0_L0Global_TOS==1)|(B0_Hlt1DiMuonHighMassDecision_TOS==1)|B0_Hlt2DiMuonDetachedJPsiDecision_TOS==1)'
tree_mc = 'Bd2JpsiK'

# %%
#read root files
df_data = rp.read_root(data_dir,key=tree_data)#,columns=branch_names_data,where=cut_string_data, flatten=True)
df_mc = rp.read_root(mc_dir,key=tree_mc,columns=branch_names_mc,where=cut_string_mc, flatten=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-5-4bc48dc51f59> in <module>()
#       1 #read root files
# ----> 2 df_data = rp.read_root(data_dir,key=tree_data)#,columns=branch_names_data,where=cut_string_data, flatten=True)
#       3 df_mc = rp.read_root(mc_dir,key=tree_mc,columns=branch_names_mc,where=cut_string_mc, flatten=True)
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/root_pandas/readwrite.py in read_root(paths, key, columns, ignore, chunksize, where, flatten, *args, **kwargs)
#     117             raise ValueError('More than one tree found in {}'.format(seed_path))
#     118
# --> 119     branches = list_branches(seed_path, key)
#     120
#     121     if not columns:
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/root_numpy/_tree.py in list_branches(filename, treename)
#      73
#      74     """
# ---> 75     return _librootnumpy.list_branches(filename, treename)
#      76
#      77
#
# root_numpy/src/tree.pyx in _librootnumpy.list_branches (root_numpy/src/_librootnumpy.cpp:81)()
#
# root_numpy/src/tree.pyx in _librootnumpy.list_structures (root_numpy/src/_librootnumpy.cpp:73)()
#
# OSError: tree 'Bd2JspiKs' not found in /fhgfs/users/chasenberg/data/2015/jpsiks/flattened/Bd2JpsiKS_data_2015_flattened_SWeights.root

# %%
#add pseudo weights with value 1 to mc 
mc_weight = np.ones(df_mc['B0_FitDaughtersConst_M'].count())
df_mc['mc_weight'] = mc_weight

# %%
#Compare sWeighted data with mc
#Now loop over all observables 
observables = bdt_features#list(df_data.columns.values)
for observable in observables: 
    lower_limit_data = df_data[observable].quantile(0.01)
    upper_limit_data = df_data[observable].quantile(0.99)
    p =Plotter('/home/chasenberg/plots/plots_weighted/quantile100')
    p.create_plots([df_data,df_mc],observable,weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'],plot_names=[observable])
    p[observable].set_range(lower_limit_data,upper_limit_data)
    p.plot()
# Out:
# WARNING: Range for plot B0_FitDaughtersConst_IP has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_IPCHI2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_P0_MinIPCHI2anyPV has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_chi2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_PT has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_PT has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_P0_IPCHI2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_decayLength has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2103             try:
# -> 2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4160)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4024)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13161)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13115)()
#
# KeyError: 'B0_FitPVConst_KS0_tau_dimless'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-b7362dc8c82a> in <module>()
#       3 observables = bdt_features#list(df_data.columns.values)
#       4 for observable in observables:
# ----> 5     lower_limit_data = df_data[observable].quantile(0.01)
#       6     upper_limit_data = df_data[observable].quantile(0.99)
#       7     p =Plotter('/home/chasenberg/plots/plots_weighted/quantile100')
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2055             return self._getitem_multilevel(key)
#    2056         else:
# -> 2057             return self._getitem_column(key)
#    2058
#    2059     def _getitem_column(self, key):
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2062         # get column
#    2063         if self.columns.is_unique:
# -> 2064             return self._get_item_cache(key)
#    2065
#    2066         # duplicate columns & possible reduce dimensionality
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3518
#    3519             if not isnull(item):
# -> 3520                 loc = self.items.get_loc(item)
#    3521             else:
#    3522                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /opt/rh/miniconda/envs/py3root6/lib/python3.4/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    2104                 return self._engine.get_loc(key)
#    2105             except KeyError:
# -> 2106                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2107
#    2108         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4160)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4024)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13161)()
#
# pandas/src/hashtable_class_helper.pxi in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:13115)()
#
# KeyError: 'B0_FitPVConst_KS0_tau_dimless'

# %%
#observables = list(df_data.columns.values)

#Loop over all entries in the dataframes and compare weighted signal with MC
for observable in observables:
    lower_limit_data = df_data[observable].quantile(0.02)
    upper_limit_data = df_data[observable].quantile(0.95)
    lower_limit_mc = df_mc[observable].quantile(0.02)
    upper_limit_mc = df_mc[observable].quantile(0.95)
    if (upper_limit_mc < upper_limit_data ) and (lower_limit_mc > lower_limit_data):
        selection_data = (df_data[observable] > lower_limit_mc) & (df_data[observable] < upper_limit_mc)
        selection_mc = (df_mc[observable] > lower_limit_mc) & (df_mc[observable] < upper_limit_mc)
        df_test = pd.DataFrame(df_data[selection_data])
        mc_test = pd.DataFrame(df_mc[selection_mc])
        p = Plotter('/home/chasenberg/plots/plots_weighted/bdt_variables')
        p.create_plots([df_test,mc_test],observable,weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'],plot_names=[observable])
        p[observable].set_range(lower_limit_mc,upper_limit_mc)
        p.plot()
    else:
        selection_data = (df_data[observable] > lower_limit_data) & (df_data[observable] < upper_limit_data)
        selection_mc = (df_mc[observable] > lower_limit_data) & (df_mc[observable] < upper_limit_data) 
        df_test = pd.DataFrame(df_data[selection_data])
        mc_test = pd.DataFrame(df_mc[selection_mc])
        p = Plotter('/home/chasenberg/plots/plots_weighted/bdt_variables')
        p.create_plots([df_test,mc_test],observable,weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'],plot_names=[observable])
        p[observable].set_range(lower_limit_data,upper_limit_data)
        p.plot()
#print(observable)
# Out:
# WARNING: Range for plot B0_FitDaughtersConst_IP has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_IPCHI2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_P0_MinIPCHI2anyPV has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_chi2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_PT has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_PT has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_P0_IPCHI2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_KS0_decayLength has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitPVConst_KS0_tau_dimless has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
# WARNING: Range for plot B0_FitDaughtersConst_J_psi_1S_P1_PT has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)

# %%
#Plot only chi2
p = Plotter('/home/chasenberg/plots/plots_weighted/bdt_variables')
p.create_plots([df_data,df_mc],'B0_FitDaughtersConst_IPCHI2',weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'])
p['B0_FitDaughtersConst_IPCHI2'].set_range(0,20)
p.plot()
# Out:
# WARNING: Range for plot B0_FitDaughtersConst_IPCHI2 has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)

# %%
#Plot only MinIPCHI2anyPV
p = Plotter('/home/chasenberg/plots/plots_weighted/bdt_variables')
p.create_plots([df_data,df_mc],'B0_FitDaughtersConst_IP',weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'])
p['B0_FitDaughtersConst_IP'].set_range(0,0.4)
p.plot()
# Out:
# WARNING: Range for plot B0_FitDaughtersConst_IP has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)

# %%
#Plot only MinIPCHI2anyPV
p = Plotter('/home/chasenberg/plots/plots_weighted/bdt_variables')
p.create_plots([df_data,df_mc],'B0_FitDaughtersConst_KS0_P0_MinIPCHI2anyPV',weightvars=['nsig_sw','mc_weight'],component_labels=['Weighted Data','MC'])
p['B0_FitDaughtersConst_KS0_P0_MinIPCHI2anyPV'].set_range(0,900)
p.plot()
# Out:
# WARNING: Range for plot B0_FitDaughtersConst_KS0_P0_MinIPCHI2anyPV has been manually set with range_part_of_selection=False.
# WARNING: Efficiencies are calculated against the full complete dataset.
# WARNING: using sumw2 errors for Weighted Data (weighted data)
# WARNING: using sumw2 errors for MC (weighted data)
